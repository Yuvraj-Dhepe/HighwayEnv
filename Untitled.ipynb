# %%
import numpy as np

# %%
# from highway_env import utils
# from highway_env.envs.common.abstract import AbstractEnv
# from highway_env.envs.common.action import Action
# from highway_env.road.road import Road, RoadNetwork
# from highway_env.utils import near_split
# from highway_env.vehicle.controller import ControlledVehicle
# from highway_env.vehicle.kinematics import Vehicle
# from gymnasium.envs.registration import register
# from gymnasium.envs import registry

from typing import Dict, Text
import gymnasium as gym
from highway_env.envs.cust_env_y import *
from highway_env.envs.cust_env_m import *
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 12
#       1 # from highway_env import utils
#       2 # from highway_env.envs.common.abstract import AbstractEnv
#       3 # from highway_env.envs.common.action import Action
#    (...)
#       8 # from gymnasium.envs.registration import register
#       9 # from gymnasium.envs import registry
#      11 from typing import Dict, Text
# ---> 12 import gymnasium as gym
#      13 from highway_env.envs.cust_env_y import *
#      14 from highway_env.envs.cust_env_m import *
#
# ModuleNotFoundError: No module named 'gymnasium'

# %%
rt_y = gym.make("rt-y-v0",render_mode = "human")
obs, info = rt_y.reset()

# %%
img = rt_y.render()
plt.imshow(img)
plt.show()

# %%
rt_m = gym.make("rt-m-v0",render_mode = "human")
obs, info = rt_m.reset()
# Out:
# /home/yuvi_dh/MSc_Life/Sem_two/HighwayEnv/venv/lib/python3.8/site-packages/gymnasium/utils/passive_env_checker.py:29: UserWarning: WARN: It seems a Box observation space is an image but the `dtype` is not `np.uint8`, actual type: float32. If the Box observation space is not an image, we recommend flattening the observation to have only a 1D vector.
#   logger.warn(
# /home/yuvi_dh/MSc_Life/Sem_two/HighwayEnv/venv/lib/python3.8/site-packages/gymnasium/utils/passive_env_checker.py:34: UserWarning: WARN: It seems a Box observation space is an image but the lower and upper bounds are not [0, 255]. Actual lower bound: -inf, upper bound: inf. Generally, CNN policies assume observations are within that range, so you may encounter an issue if the observation values are not.
#   logger.warn(

# %%
# O: Zoom in, L: Zoom Out, M: Move Right, K: Move Left 
# Buttons for viewing the maps properly
for i in range(1000):
    obs, reward, terminated, truncated, info = rt_m.step(rt_m.action_space.sample())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 # O: Zoom in, L: Zoom Out, M: Move Right, K: Move Left
#       2 # Buttons for viewing the maps properly
#       3 for i in range(1000):
# ----> 4     obs, reward, terminated, truncated, info = rt_m.step(rt_m.action_space.sample())
#
# File ~/MSc_Life/Sem_two/HighwayEnv/venv/lib/python3.8/site-packages/gymnasium/wrappers/order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~/MSc_Life/Sem_two/HighwayEnv/venv/lib/python3.8/site-packages/gymnasium/wrappers/env_checker.py:49, in PassiveEnvChecker.step(self, action)
#      47     return env_step_passive_checker(self.env, action)
#      48 else:
# ---> 49     return self.env.step(action)
#
# File ~/MSc_Life/Sem_two/HighwayEnv/highway_env/envs/common/abstract.py:235, in AbstractEnv.step(self, action)
#     232     raise NotImplementedError("The road and vehicle must be initialized in the environment implementation")
#     234 self.time += 1 / self.config["policy_frequency"]
# --> 235 self._simulate(action)
#     237 obs = self.observation_type.observe()
#     238 reward = self._reward(action)
#
# File ~/MSc_Life/Sem_two/HighwayEnv/highway_env/envs/common/abstract.py:264, in AbstractEnv._simulate(self, action)
#     261     # Automatically render intermediate simulation steps if a viewer has been launched
#     262     # Ignored if the rendering is done offscreen
#     263     if frame < frames - 1:  # Last frame will be rendered through env.render() as usual
# --> 264         self._automatic_rendering()
#     266 self.enable_auto_render = False
#
# File ~/MSc_Life/Sem_two/HighwayEnv/highway_env/envs/common/abstract.py:325, in AbstractEnv._automatic_rendering(self)
#     323     self._record_video_wrapper.video_recorder.capture_frame()
#     324 else:
# --> 325     self.render()
#
# File ~/MSc_Life/Sem_two/HighwayEnv/highway_env/envs/common/abstract.py:287, in AbstractEnv.render(self)
#     283     self.viewer = EnvViewer(self)
#     285 self.enable_auto_render = True
# --> 287 self.viewer.display()
#     289 if not self.viewer.offscreen:
#     290     self.viewer.handle_events()
#
# File ~/MSc_Life/Sem_two/HighwayEnv/highway_env/envs/common/graphics.py:103, in EnvViewer.display(self)
#     100     return
#     102 self.sim_surface.move_display_window_to(self.window_position())
# --> 103 RoadGraphics.display(self.env.road, self.sim_surface)
#     105 if self.vehicle_trajectory:
#     106     VehicleGraphics.display_trajectory(
#     107         self.vehicle_trajectory,
#     108         self.sim_surface,
#     109         offscreen=self.offscreen)
#
# File ~/MSc_Life/Sem_two/HighwayEnv/highway_env/road/graphics.py:241, in RoadGraphics.display(road, surface)
#     239 for _to in road.network.graph[_from].keys():
#     240     for l in road.network.graph[_from][_to]:
# --> 241         LaneGraphics.display(l, surface)
#
# File ~/MSc_Life/Sem_two/HighwayEnv/highway_env/road/graphics.py:130, in LaneGraphics.display(cls, lane, surface)
#     128 for side in range(2):
#     129     if lane.line_types[side] == LineType.STRIPED:
# --> 130         cls.striped_line(lane, surface, stripes_count, s0, side)
#     131     elif lane.line_types[side] == LineType.CONTINUOUS:
#     132         cls.continuous_curve(lane, surface, stripes_count, s0, side)
#
# File ~/MSc_Life/Sem_two/HighwayEnv/highway_env/road/graphics.py:151, in LaneGraphics.striped_line(cls, lane, surface, stripes_count, longitudinal, side)
#     149 ends = longitudinal + np.arange(stripes_count) * cls.STRIPE_SPACING + cls.STRIPE_LENGTH
#     150 lats = [(side - 0.5) * lane.width_at(s) for s in starts]
# --> 151 cls.draw_stripes(lane, surface, starts, ends, lats)
#
# File ~/MSc_Life/Sem_two/HighwayEnv/highway_env/road/graphics.py:202, in LaneGraphics.draw_stripes(cls, lane, surface, starts, ends, lats)
#     200 ends = np.clip(ends, 0, lane.length)
#     201 for k, _ in enumerate(starts):
# --> 202     if abs(starts[k] - ends[k]) > 0.5 * cls.STRIPE_LENGTH:
#     203         pygame.draw.line(surface, surface.WHITE,
#     204                          (surface.vec2pix(lane.position(starts[k], lats[k]))),
#     205                          (surface.vec2pix(lane.position(ends[k], lats[k]))),
#     206                          max(surface.pix(cls.STRIPE_WIDTH), 1))
#
# KeyboardInterrupt:

# %%
plt.imshow(rt_m.render())
